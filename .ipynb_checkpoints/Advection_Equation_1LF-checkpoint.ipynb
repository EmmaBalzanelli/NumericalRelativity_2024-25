# %% [markdown]
# # Advection Equation
#
# Here we solve the advection equation $u_t + a u_x=0$ using as an initial condition a gaussian profile $u(x,t=0)=\exp{[-(x-x_0)^2]}$ with $x_0=5$.
#
# We use a domain $x\in [0,10]$ with periodic boundary conditions.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# !pip install imageio[ffmpeg]
import imageio.v2 as imageio
import glob
# Out:
# Requirement already satisfied: imageio[ffmpeg] in c:\users\balza\anaconda3copia\lib\site-packages (2.33.1)
# Requirement already satisfied: numpy in c:\users\balza\anaconda3copia\lib\site-packages (from imageio[ffmpeg]) (1.26.4)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\balza\anaconda3copia\lib\site-packages (from imageio[ffmpeg]) (10.4.0)
# Requirement already satisfied: imageio-ffmpeg in c:\users\balza\anaconda3copia\lib\site-packages (from imageio[ffmpeg]) (0.6.0)
# Requirement already satisfied: psutil in c:\users\balza\anaconda3copia\lib\site-packages (from imageio[ffmpeg]) (5.9.0)

# %% [markdown]
# ## Studied cases:
# - J = 101, c_f = 0.5
# - J = 101, c_f = 0.8
# - J = 301, c_f = 0.5

# %%
#define the speed a
a=1.0

# Define the domain
L = 10.0     # Domain length
nx = 301    # Number of grid points
dx = L/(nx-1)   # Grid spacing
x = np.linspace(0, L, nx)

##print(x,'\n',dx) #just a check

# Define the time step and the final time
cf = 0.5
dt = cf*dx/a   # Time step
t_final = 20.0

print('nx=',nx)
print('dx=',dx)
print('dt=',dt)
print('Number of iterations=',t_final/dt)


# Define the initial condition
x0=5
u_initial = np.exp(-(x-x0)**2)

# Initialize the solution array
u_current = u_initial.copy()

#we create arrays where we will store the time and the l2norm
#l2norm, time for case 1
#l2norm_cf, time _cf for case 2
#l2norm_301, time_301 for case 
l2norm_301=[]
l2norm_301.append(np.sqrt(np.sum(u_current**2)/len(u_current)))

time_301=[]
time_301.append(0.0)
# Out:
# nx= 301
# dx= 0.03333333333333333
# dt= 0.016666666666666666
# Number of iterations= 1200.0

# %%
#create directory where to save images
print(os.getcwd())

os.makedirs('./images_LF', exist_ok=True)
os.listdir('./')
# Out:
# C:\Users\balza\Desktop\Numerical Relativity
# ['.ipynb_checkpoints',
#  'Advection_Equation_1FTCS.ipynb',
#  'Advection_Equation_1LF.ipynb',
#  'Advection_Equation_Leapfrog.ipynb',
#  'Advection_Equation_Leapfrog_OF_BC.ipynb',
#  'Advection_Equation_LW.ipynb',
#  'Advection_Equation_stepLeapfrog.ipynb',
#  'Advection_Equation_StepLF.ipynb',
#  'Advection_Equation_StepLW.ipynb',
#  'Burgers_eq.ipynb',
#  'images_BURG',
#  'images_BURG_non',
#  'images_FTCS',
#  'images_leapfrog',
#  'images_LF',
#  'images_LW',
#  'images_stepleapfrog',
#  'images_stepLF',
#  'images_stepLW',
#  'l2norm_FTCS.dat',
#  'l2norm_LAX.dat',
#  'l2norm_LAXWENDROFF.dat',
#  'l2norm_LEAPFROG.dat',
#  'movie_BURG.mp4',
#  'movie_BURG_non.mp4',
#  'movie_FTCS.mp4',
#  'movie_leapfrog.mp4',
#  'movie_LF.mp4',
#  'movie_LW.mp4',
#  'movie_step.mp4',
#  'movie_stepleapfrog.mp4',
#  'movie_stepLF.mp4',
#  'movie_stepLW.mp4']

# %%
# Initilize time and iteration counter
t = 0.0
i = 0

u_iter=[]
t_iter=[]

#save the initial conditions
plt.plot(x, u_current)
plt.title('Time='+str(round(t,2)))
plt.ylim(0,1.1)
plt.savefig('./images_LF/fig_'+str(i).zfill(5)+'.png', dpi=200)
plt.close()

#solve the advection equation
while t < t_final:
    # Compute the new solution using the FTCS method
    # Note: np.roll(u_current, -1) is equivalent to u(j+1) and
    #       np.roll(u_current,  1) is equivalent to u(j-1)
    # using np.roll is equivalent to use periodic boundary conditions
    u_next = 0.5*(np.roll(u_current, -1) + np.roll(u_current, 1)) - a*dt/(2*dx)*(np.roll(u_current, -1) - np.roll(u_current, 1))    
    
    # Update the solution
    u_current = u_next.copy()
    
    
    #advance the time 
    t += dt
    i += 1
    
    #compute the l2 norm and add the time to the time vector
    #cange them for the three cases
    l2norm_301.append(np.sqrt(np.sum(u_current**2)/len(u_current)))
    time_301.append(t)
    
    #plot the current result and save in an image every 10 iterations
    if (i%10==0):
        u_iter.append(u_current)
        t_iter.append(t)
        plt.plot(x, u_current)
        plt.title('Time='+str(round(t,2)))
        plt.ylim(0,1.1)
        plt.savefig('./images_LF/fig_'+str(i).zfill(5)+'.png', dpi=200)
        plt.close()

# %%
# Plot the final solution
'''fig = plt.plot(figsize=(9,6))
plt.plot(x, u_initial, label='Initial')
plt.plot(x, u_iter[20], label='t = %s' %round(t_iter[20],2))
plt.plot(x, u_iter[30], label='t = %s' %round(t_iter[30],2))
plt.plot(x, u_current, label='Final')
plt.title('Advection Equation with Lax-Friedrichs scheme', fontsize=14)
#plt.ylim(0,1.1)
plt.xlabel('x')
plt.ylabel('u')
plt.legend()
plt.savefig('./images_LF/LF_plot_1_301.png', dpi=200)
plt.show()'''

#canged title end name of the figure for each studied case

fig, ax = plt.subplots(2,2, figsize=(9, 6), constrained_layout=True)
ax[0,0].plot(x, u_initial, label='Initial')
ax[0,1].plot(x, u_iter[62], label='t = %s' %round(t_iter[62],2))
ax[1,0].plot(x, u_iter[92], label='t = %s' %round(t_iter[92],2))
ax[1,1].plot(x, u_current, label='Final')
fig.suptitle('Advection Equation with Lax-Friedrichs scheme', fontsize=16)
for i in range(len(ax[:,0])):
    for j in range(len(ax[0,:])):
        ax[i,j].set_xlabel('x')
        ax[i,j].set_ylabel('u')
        ax[i,j].set_ylim(0,1.1)
        ax[i,j].legend()
        ax[i,j].grid(True)
#plt.savefig('./images_LF/LF_plot_2_301.png', dpi=200)
plt.show()

# %%
# set the directory where your images are stored
directory = "./images_LF/"

# get the list of image files in the directory
files = os.listdir(directory)

print(files, '\n')

# sort the files in alphanumeric order
images_files=sorted(glob.glob('./images_LF/fig_*.png'))

print(images_files)
# Out:
# ['fig_00000.png', 'fig_00010.png', 'fig_00020.png', 'fig_00030.png', 'fig_00040.png', 'fig_00050.png', 'fig_00060.png', 'fig_00070.png', 'fig_00080.png', 'fig_00090.png', 'fig_00100.png', 'fig_00110.png', 'fig_00120.png', 'fig_00130.png', 'fig_00140.png', 'fig_00150.png', 'fig_00160.png', 'fig_00170.png', 'fig_00180.png', 'fig_00190.png', 'fig_00200.png', 'fig_00210.png', 'fig_00220.png', 'fig_00230.png', 'fig_00240.png', 'fig_00250.png', 'fig_00260.png', 'fig_00270.png', 'fig_00280.png', 'fig_00290.png', 'fig_00300.png', 'fig_00310.png', 'fig_00320.png', 'fig_00330.png', 'fig_00340.png', 'fig_00350.png', 'fig_00360.png', 'fig_00370.png', 'fig_00380.png', 'fig_00390.png', 'fig_00400.png', 'fig_00410.png', 'fig_00420.png', 'fig_00430.png', 'fig_00440.png', 'fig_00450.png', 'fig_00460.png', 'fig_00470.png', 'fig_00480.png', 'fig_00
560.png', './images_LF\\fig_00570.png', './images_LF\\fig_00580.png', './images_LF\\fig_00590.png', './images_LF\\fig_00600.png', './images_LF\\fig_00610.png', './images_LF\\fig_00620.png', './images_LF\\fig_00630.png', './images_LF\\fig_00640.png', './images_LF\\fig_00650.png', './images_LF\\fig_00660.png', './images_LF\\fig_00670.png', './images_LF\\fig_00680.png', './images_LF\\fig_00690.png', './images_LF\\fig_00700.png', './images_LF\\fig_00710.png', './images_LF\\fig_00720.png', './images_LF\\fig_00730.png', './images_LF\\fig_00740.png', './images_LF\\fig_00750.png', './images_LF\\fig_00760.png', './images_LF\\fig_00770.png', './images_LF\\fig_00780.png', './images_LF\\fig_00790.png', './images_LF\\fig_00800.png', './images_LF\\fig_00810.png', './images_LF\\fig_00820.png', './images_LF\\fig_00830.png', './images_LF\\fig_00840.png', './images_LF\\fig_00850.png', './images_LF\\fig_00860.png', './images_LF\\fig_00870.png', './images_LF\\fig_00880.png', './images_LF\\fig_00890.png', './images_LF\\fig_00900.png', './images_LF\\fig_00910.png', './images_LF\\fig_00920.png', './images_LF\\fig_00930.png', './images_LF\\fig_00940.png', './images_LF\\fig_00950.png', './images_LF\\fig_00960.png', './images_LF\\fig_00970.png', './images_LF\\fig_00980.png', './images_LF\\fig_00990.png', './images_LF\\fig_01000.png', './images_LF\\fig_01010.png', './images_LF\\fig_01020.png', './images_LF\\fig_01030.png', './images_LF\\fig_01040.png', './images_LF\\fig_01050.png', './images_LF\\fig_01060.png', './images_LF\\fig_01070.png', './images_LF\\fig_01080.png', './images_LF\\fig_01090.png', './images_LF\\fig_01100.png', './images_LF\\fig_01110.png', './images_LF\\fig_01120.png', './images_LF\\fig_01130.png', './images_LF\\fig_01140.png', './images_LF\\fig_01150.png', './images_LF\\fig_01160.png', './images_LF\\fig_01170.png', './images_LF\\fig_01180.png', './images_LF\\fig_01190.png', './images_LF\\fig_01200.png']

# %%
output_video_path = os.path.abspath('./movie_LF.mp4')
with imageio.get_writer(output_video_path, fps=20, codec='libx264') as writer:
    for file in images_files:
        image = imageio.imread(file)
        writer.append_data(image)

# %%
# don't worry about the code in this cell, it is just to let you 
# display the movies you generated above in Jupyter notebook
from IPython.display import HTML

HTML("""
<div align="middle">
<video width="80%" controls>
      <source src="./movie_LF.mp4" type="video/mp4">
</video></div>""")
# Out:
# <div align="middle">
# <video width="80%" controls>
#       <source src="./movie_LF.mp4" type="video/mp4">
# </video></div>

# %%
plt.plot(time,l2norm)
plt.show()

# %% [markdown]
# ## L2-norm for all the three studied cases

# %%
#Compare with data stored
l2_saved=np.genfromtxt('./l2norm_LAX.dat', comments='#')

fig= plt.plot(figsize=(9, 6), constrained_layout=True)
plt.plot(l2_saved[:,0], l2_saved[:,1], '+', label='L2-norm data')
plt.plot(time,l2norm, label='$J=101, c_F=0.5$')
plt.plot(time_cf,l2norm_cf, label='$J=101, c_F=0.8$')
plt.plot(time_301,l2norm_301,label='$J=301, c_F=0.5$')
#plt.plot(time_2,l2norm_2, label='$J=401, c_F=0.8$')
plt.grid(True)
plt.xlabel('t')
plt.ylabel('L2-norm')
#plt.yscale('log')
plt.legend()
plt.title('L2-norms for Lax-Friedrichs \n', fontsize=14)
plt.savefig('./images_LF/L2_LF_plot.png', dpi=200)
plt.show()
